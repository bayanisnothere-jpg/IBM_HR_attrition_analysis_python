# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !jupyter nbconvert --to python "/content/drive/MyDrive/notebooks/01_data_validation.ipynb" --output-dir "/tmp"
# %run "/tmp/01_data_validation.py"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/notebooks/01_data_validation.ipynb to python
# [NbConvertApp] Writing 779 bytes to /tmp/01_data_validation.py
# Using Colab cache for faster access to the 'ibm-hr-analytics-attrition-dataset' dataset.
# Path to dataset files: /kaggle/input/ibm-hr-analytics-attrition-dataset
# ...

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# ###lowering case

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        df[col]=df[col].str.lower()

# %% [markdown]
# ###droping unnecessary column(all rows contain the same info)

# %%
columns_to_drop = ['EmployeeCount', 'StandardHours', 'Over18']
existing_columns = [col for col in columns_to_drop if col in df.columns]
df = df.drop(columns=existing_columns)

# %% [markdown]
# ###changing datatypes

# %%
df['Attrition'] = df['Attrition'].map({'yes': True, 'no': False})
df['Attrition'] = df['Attrition'].astype('boolean')
df['OverTime']=df['OverTime'].map({'yes': True, 'no': False})
df['OverTime'] = df['OverTime'].astype('boolean')
print(df['Attrition'].dtype, df['OverTime'].dtype)
# Out:
# boolean boolean

# %% [markdown]
# ### drop duplicates and nulls

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
df.head(2)
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       True      travel_rarely       1102                   sales
# 1   49      False  travel_frequently        279  research & development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  life sciences               1
# 1                 8          1  life sciences               2
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# 1                        3  ...                 4                         4
#
#    StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance  \
# 0                 0                  8                     0                1
# 1                 1                 10                     3                3
#
#   YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# ...

# %% [markdown]
# ##Saving Clean Data(ready to work)

# %%
df.to_csv('/content/drive/MyDrive/python_clean_data.csv')
